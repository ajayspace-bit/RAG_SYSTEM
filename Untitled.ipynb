# %% [markdown]
# ## 1. Install libraries

# %%
# !pip -q install pypdf chromadb google-genai
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\ajayw\appdata\local\programs\python\python310\lib\site-packages (6.17.0)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\ajayw\appdata\local\programs\python\python310\lib\site-packages (from pypdf) (4.15.0)

# %% [markdown]
# ## 2.Configure Gemini API key

# %%
import os
from getpass import getpass

if not os.environ.get("GEMINI_API_KEY"):
    os.environ["GEMINI_API_KEY"] = getpass("Enter your Gemini API key: ")

from google import genai

client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

print("Gemini client configured successfully.")
# Out:
# Enter your Gemini API key:  ········
# Gemini client configured successfully.

# %% [markdown]
# ## 3. Upload PDF

# %%
from google.colab import files

uploaded = files.upload()

pdf_path = next(iter(uploaded.keys()))

print("Uploaded file:", RAG_HR_Policy_20_Page.pdf)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from google.colab import files
#       3 uploaded = files.upload()
#       5 pdf_path = next(iter(uploaded.keys()))
#
# ModuleNotFoundError: No module named 'google.colab'
